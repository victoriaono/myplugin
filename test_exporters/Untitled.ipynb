# %%
# Create random data with numpy
import numpy as np
np.random.seed(1)

N = 100
random_x = np.linspace(0, 1, N)
random_y0 = np.random.randn(N) + 5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N) - 5

fig = go.Figure()

marker = {}
marker['color'] = 'red'
line = {}
line['dash'] = 'solid'
line['width'] = 1

# Add traces
fig.add_scatter(x=random_x, y=random_y1,
                    mode='lines+markers',
                    name='lines+markers',
                    marker=marker,
                    line=line)
fig.show()
# Out:
# <div>                            <div id="1b284503-29a9-44d6-b1f5-2af6e3a5ff5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b284503-29a9-44d6-b1f5-2af6e3a5ff5d")) {                    Plotly.newPlot(                        "1b284503-29a9-44d6-b1f5-2af6e3a5ff5d",                        [{"line":{"dash":"solid","width":1},"marker":{"color":"red"},"mode":"lines+markers","name":"lines+markers","x":[0.0,0.010101010101010102,0.020202020202020204,0.030303030303030304,0.04040404040404041,0.05050505050505051,0.06060606060606061,0.07070707070707072,0.08080808080808081,0.09090909090909091,0.10101010101010102,0.11111111111111112,0.12121212121212122,0.13131313131313133,0.14141414141414144,0.15151515151515152,0.16161616161616163,0.17171717171717174,0.1818181
# ...
